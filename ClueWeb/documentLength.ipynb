# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
docLengths = np.loadtxt("docLengths.csv")
averageLength = docLengths.mean()
print(f"Smallest document: {docLengths.min()}")
print(f"Largest document: {docLengths.max()}")
print(f"Average length: {averageLength}")
# Out:
# Smallest document: 10.0
# Largest document: 1152428.0
# Average length: 1162.56863225676

# %%
data = {"length" : docLengths}
docLengths = pd.DataFrame(data=data)
display(docLengths)
# Out:
#          length
# 0        1399.0
# 1        1393.0
# 2         642.0
# 3          75.0
# 4        1651.0
# ...         ...
# 1048569  3641.0
# 1048570  3395.0
# 1048571   990.0
# 1048572   994.0
# 1048573  1358.0
#
# [1048574 rows x 1 columns]

# %%
sns.boxplot(data=docLengths, x="length")
# Out:
# <Axes: xlabel='length'>

# %%
sns.countplot(x="length",data=docLengths)
# Out:
# <Axes: xlabel='length', ylabel='count'>
