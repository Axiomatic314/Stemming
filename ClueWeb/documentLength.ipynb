# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib.ticker as ticker

# %%
docLengths = np.loadtxt("docLengths.csv")
averageLength = docLengths.mean()
minLength = docLengths.min()
maxLength = docLengths.max()
print(f"Smallest document: {minLength}")
print(f"Largest document: {maxLength}")
print(f"Average length: {averageLength}")
# Out:
# Smallest document: 4.0
# Largest document: 1883663.0
# Average length: 1254.3844453014954

# %%
data = {"length" : docLengths}
docLengths = pd.DataFrame(data=data)
display(docLengths)
# Out:
#           length
# 0         1399.0
# 1         1393.0
# 2          642.0
# 3           75.0
# 4         1651.0
# ...          ...
# 52342276   756.0
# 52342277   765.0
# 52342278   664.0
# 52342279   863.0
# 52342280   850.0
#
# [52342281 rows x 1 columns]

# %%
sns.boxplot(data=docLengths, x="length")
# Out:
# <Axes: xlabel='length'>

# %%
ax = sns.countplot(x="length",data=docLengths)
currentXTicks = ax.get_xticks()[-1]
xTicks = np.linspace(currentXTicks[0], currentXTicks[-1], 11)
ax.set_xticks(xTicks)
# plt.autoscale()
# ax.set_xlim(0,maxLength)
# ax.set_yscale("log")
# ax.set_xscale("linear")
# ax.axes.xaxis.set_major_locator(ticker.MultipleLocator(2500))
# ax.axes.xaxis.set_major_formatter(ticker.ScalarFormatter())
plt.show()

# %%
# sampledDocLengths = docLengths.sample(frac=1)
sampledDocLengths = docLengths.sample(frac=0.001)
sampledDocLengths["LogLength"] = np.log(sampledDocLengths["length"])

# %%
plt.hist(docLengths["length"], bins=100)
plt.yscale("log")
plt.xlabel("Document Length")
plt.ylabel("Number of Documents (log)")
plt.title("Number of Documents by Document Length")
plt.show()

# %%
plt.hist(docLengths["length"], bins=100, cumulative=True)
plt.yscale("log")
plt.xlabel("Document Length")
plt.ylabel("Number of Documents (Cumulative, log)")
plt.title("Number of Documents by Document Length")
plt.show()

# %%
sns.histplot(sampledDocLengths, x="length", stat="proportion", cumulative=True, log_scale=True)
plt.xlabel("Document Length (Log)")
plt.ylabel("Proportion of Documents (Cumulative)")
plt.title("Cumulative Proportion of Documents by Document Length")
plt.show()

# %%
sns.boxenplot(sampledDocLengths, x="LogLength")
# Out:
# <Axes: xlabel='LogLength'>

# %%
sns.violinplot(sampledDocLengths, x="LogLength")
# Out:
# <Axes: xlabel='LogLength'>

# %%
# Consider using this to visualize DocLength with DocLengthWithoutScriptTags
# https://matplotlib.org/stable/gallery/lines_bars_and_markers/scatter_hist.html#sphx-glr-gallery-lines-bars-and-markers-scatter-hist-py
